# %%
import pandas as pd
import numpy as np
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord

# %%
with open('../../config/oc43_full_reference.gb', "r") as handle:
    for record in SeqIO.parse(handle, "genbank"):
        print(record.seq[210:13332]+record.seq[13331:21497])
# Out:
# ...
